# %%
from ultralytics import YOLO

# model = YOLO('yolov8n.pt')
model = YOLO('best.pt')

# %%
model = YOLO('best.pt')
results = model.predict(source='datasets/test/images/Valorant-Screenshot-2022-02-05-02-07-22-49_png.rf.6756dfeab0d26f2390c1b5ecd3dd32d4.jpg', conf=0.25, save=True)
# Out:
# image 1/1 c:\Drive D\Project3.2\valo\datasets\test\images\Valorant-Screenshot-2022-02-05-02-07-22-49_png.rf.6756dfeab0d26f2390c1b5ecd3dd32d4.jpg: 640x640 1 enemyBody, 1 enemyHead, 84.3ms
# Speed: 23.5ms preprocess, 84.3ms inference, 1574.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict

# %%
from IPython.display import Image
Image('datasets/test/images/Valorant-Screenshot-2022-02-05-02-07-22-49_png.rf.6756dfeab0d26f2390c1b5ecd3dd32d4.jpg')

# %%
Image('runs/detect/predict/Valorant-Screenshot-2022-02-05-02-07-22-49_png.rf.6756dfeab0d26f2390c1b5ecd3dd32d4.jpg')

# %%
results = model.predict(source='datasets/test/images/', conf=0.25, save=True)
# Out:
# image 1/51 c:\Drive D\Project3.2\valo\datasets\test\images\-60-Deathmatch-40-_-0-YouTube-Brave-12_16_2023-2_17_55-AM_png.rf.83b028aec4841427e010421ff43990b2.jpg: 640x640 (no detections), 116.3ms
# image 2/51 c:\Drive D\Project3.2\valo\datasets\test\images\VALORANT-12_16_2023-7_49_06-PM-1-_png.rf.d4e89db38dd244f37ea17b0cb39d282f.jpg: 640x640 (no detections), 114.2ms
# image 3/51 c:\Drive D\Project3.2\valo\datasets\test\images\VALORANT-12_16_2023-7_50_56-PM_png.rf.72be5202f8f8059b51d2b70a414ef145.jpg: 640x640 (no detections), 38.4ms
# image 4/51 c:\Drive D\Project3.2\valo\datasets\test\images\VALORANT-12_16_2023-7_51_22-PM-1-_png.rf.5582b5e00586bc769edb57ab53127a10.jpg: 640x640 1 enemyBody, 1 enemyHead, 12.8ms
# image 5/51 c:\Drive D\Project3.2\valo\datasets\test\images\VALORANT-12_16_2023-7_51_44-PM_png.rf.b52b393509319f9af7688199936761c5.jpg: 640x640 1 enemyBody, 1 enemyHead, 12.2ms
# ...

# %%
results = model.predict(source='ss/', conf=0.25, save=True)
# Out:
# image 1/4 c:\Drive D\Project3.2\valo\ss\Screenshot 2024-05-11 002945.png: 416x640 1 enemyHead, 139.4ms
# image 2/4 c:\Drive D\Project3.2\valo\ss\Screenshot 2024-05-11 003006.png: 480x640 1 enemyBody, 154.1ms
# image 3/4 c:\Drive D\Project3.2\valo\ss\Screenshot 2024-05-11 003010.png: 544x640 1 enemyBody, 1 enemyHead, 29.2ms
# image 4/4 c:\Drive D\Project3.2\valo\ss\Screenshot 2024-05-11 003025.png: 384x640 1 enemyBody, 27.0ms
# Speed: 11.7ms preprocess, 87.4ms inference, 701.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict3

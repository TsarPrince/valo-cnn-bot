# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.11  Python-3.10.2 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Setup complete  (12 CPUs, 7.3 GB RAM, 420.2/447.5 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Drive D\Project3.2\valo

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='./data/train/images/VALORANT-12_16_2023-7_48_58-PM_png.rf.519ddb48931a44eedcb4201f8d911042.jpg', conf=0.25, save=True)
# Out:
# image 1/1 c:\Drive D\Project3.2\valo\data\train\images\VALORANT-12_16_2023-7_48_58-PM_png.rf.519ddb48931a44eedcb4201f8d911042.jpg: 640x640 1 refrigerator, 14.5ms
# Speed: 4.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict

# %%
Image('data/train/images/VALORANT-12_16_2023-7_48_58-PM_png.rf.519ddb48931a44eedcb4201f8d911042.jpg')

# %%
Image('runs/detect/predict/VALORANT-12_16_2023-7_48_58-PM_png.rf.519ddb48931a44eedcb4201f8d911042.jpg')

# %%
results[0].boxes.xyxy # coordinates of bounding boxes
# Out:
# tensor([[119.1853,  61.4196, 209.8874, 359.7755]], device='cuda:0')

# %%
results[0].boxes.conf # confidence
# Out:
# tensor([0.2595], device='cuda:0')

# %%
results[0].boxes.cls # class
# Out:
# tensor([72.], device='cuda:0')

# %%
results = model.predict(source='./data/train/images/VALORANT-12_16_2023-7_50_43-PM_png.rf.c256a93ea9b2489ce18f7bac562673c6.jpg', conf=0.25, save=True)
# Out:
# image 1/1 c:\Drive D\Project3.2\valo\data\train\images\VALORANT-12_16_2023-7_50_43-PM_png.rf.c256a93ea9b2489ce18f7bac562673c6.jpg: 640x640 1 person, 132.2ms
# Speed: 8.0ms preprocess, 132.2ms inference, 22.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict

# %%
Image(filename='data/train/images/VALORANT-12_16_2023-7_50_43-PM_png.rf.c256a93ea9b2489ce18f7bac562673c6.jpg')

# %%
Image(filename='runs/detect/predict/VALORANT-12_16_2023-7_50_43-PM_png.rf.c256a93ea9b2489ce18f7bac562673c6.jpg')
